# %%
import gym

from stable_baselines3 import A2C

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env = gym.make('CartPole-v1')

model = A2C('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.7     |
# |    ep_rew_mean        | 17.7     |
# | time/                 |          |
# |    fps                | 3547     |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | -0.109   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -3.57    |
# |    value_loss         | 27.4     |
# ------------------------------------
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:216: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:228: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `return_info` to return information from the environment resetting.
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:233: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.3     |
# |    ep_rew_mean        | 18.3     |
# | time/                 |          |
# |    fps                | 3550     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.67    |
# |    explained_variance | -0.3     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.55     |
# |    value_loss         | 9.53     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.6     |
# |    ep_rew_mean        | 21.6     |
# | time/                 |          |
# |    fps                | 3593     |
# |    iterations         | 300      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.657   |
# |    explained_variance | -0.0749  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -4.95    |
# |    value_loss         | 133      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.8     |
# |    ep_rew_mean        | 23.8     |
# | time/                 |          |
# |    fps                | 3483     |
# |    iterations         | 400      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.63    |
# |    explained_variance | -0.209   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.55     |
# |    value_loss         | 7.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 25.4     |
# |    ep_rew_mean        | 25.4     |
# | time/                 |          |
# |    fps                | 3516     |
# |    iterations         | 500      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.625   |
# |    explained_variance | 0.0739   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.52     |
# |    value_loss         | 6.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.9     |
# |    ep_rew_mean        | 28.9     |
# | time/                 |          |
# |    fps                | 3584     |
# |    iterations         | 600      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | -0.00142 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.974    |
# |    value_loss         | 5.5      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 31.7     |
# |    ep_rew_mean        | 31.7     |
# | time/                 |          |
# |    fps                | 3627     |
# |    iterations         | 700      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.577   |
# |    explained_variance | 0.0285   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.25     |
# |    value_loss         | 4.95     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 35.4     |
# |    ep_rew_mean        | 35.4     |
# | time/                 |          |
# |    fps                | 3642     |
# |    iterations         | 800      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.483   |
# |    explained_variance | -0.0188  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.647    |
# |    value_loss         | 4.52     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.1     |
# |    ep_rew_mean        | 39.1     |
# | time/                 |          |
# |    fps                | 3602     |
# |    iterations         | 900      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.515   |
# |    explained_variance | 0.0125   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.18     |
# |    value_loss         | 3.92     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 43       |
# |    ep_rew_mean        | 43       |
# | time/                 |          |
# |    fps                | 3613     |
# |    iterations         | 1000     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.533   |
# |    explained_variance | -0.00367 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.12     |
# |    value_loss         | 3.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 46.3     |
# |    ep_rew_mean        | 46.3     |
# | time/                 |          |
# |    fps                | 3632     |
# |    iterations         | 1100     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.607   |
# |    explained_variance | -0.004   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.683    |
# |    value_loss         | 2.89     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50.3     |
# |    ep_rew_mean        | 50.3     |
# | time/                 |          |
# |    fps                | 3618     |
# |    iterations         | 1200     |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | 0.00162  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.739    |
# |    value_loss         | 2.43     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 56.5      |
# |    ep_rew_mean        | 56.5      |
# | time/                 |           |
# |    fps                | 3630      |
# |    iterations         | 1300      |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.587    |
# |    explained_variance | -0.000139 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.658     |
# |    value_loss         | 2.02      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 61        |
# |    ep_rew_mean        | 61        |
# | time/                 |           |
# |    fps                | 3611      |
# |    iterations         | 1400      |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -0.481    |
# |    explained_variance | -0.000178 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 0.576     |
# |    value_loss         | 1.64      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 63.6     |
# |    ep_rew_mean        | 63.6     |
# | time/                 |          |
# |    fps                | 3623     |
# |    iterations         | 1500     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 3.59e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.398    |
# |    value_loss         | 1.31     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 67.8     |
# |    ep_rew_mean        | 67.8     |
# | time/                 |          |
# |    fps                | 3636     |
# |    iterations         | 1600     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.407   |
# |    explained_variance | 0.000211 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.468    |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 71.8     |
# |    ep_rew_mean        | 71.8     |
# | time/                 |          |
# |    fps                | 3642     |
# |    iterations         | 1700     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | 6.75e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.448    |
# |    value_loss         | 0.782    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 74.4     |
# |    ep_rew_mean        | 74.4     |
# | time/                 |          |
# |    fps                | 3652     |
# |    iterations         | 1800     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.492   |
# |    explained_variance | 1.44e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.334    |
# |    value_loss         | 0.566    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 77       |
# |    ep_rew_mean        | 77       |
# | time/                 |          |
# |    fps                | 3663     |
# |    iterations         | 1900     |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.569   |
# |    explained_variance | 3.34e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.177    |
# |    value_loss         | 0.383    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 79.9      |
# |    ep_rew_mean        | 79.9      |
# | time/                 |           |
# |    fps                | 3671      |
# |    iterations         | 2000      |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.495    |
# |    explained_variance | -6.28e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 0.303     |
# |    value_loss         | 0.241     |
# -------------------------------------
# Unexpected exception formatting exception. Falling back to standard exception
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:297: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`
# /opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:305: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py", line 15, in <module>
#     import pyglet
# ModuleNotFoundError: No module named 'pyglet'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/3p/9p26d0_s02b4tzgwjq2xx6mh0000gn/T/ipykernel_59431/3858618558.py", line 10, in <cell line: 7>
#     env.render()
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/core.py", line 343, in render
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py", line 51, in render
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/wrappers/env_checker.py", line 55, in render
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/utils/passive_env_checker.py", line 310, in passive_env_render_check
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/envs/classic_control/cartpole.py", line 179, in render
#     from gym.envs.classic_control import rendering
#   File "/opt/homebrew/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py", line 17, in <module>
#     raise ImportError(
# ImportError:
#     Cannot import pyglet.
#     HINT: you can install pyglet directly via 'pip install pyglet'.
#     But if you really just want to install all Gym dependencies and not have to think about it,
#     'pip install -e .[all]' or 'pip install gym[all]' will do it.
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/opt/homebrew/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/homebrew/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/opt/homebrew/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
